# %% [markdown]
# # 20MAI0010-NEHA RAJEEV SAINUDEEN -Task2(ii)

# %% [markdown]
# https://github.com/nehrjv/Machine-Learning-Lab-assignment

# %%
#importing the libraries
import pandas as pd
import numpy as np

# %%
#loading the dataset
data = pd.read_csv('E:/AI & ML NEHA/winter main/ml techniques/loan.csv')

# %%
#display the data in the csv file
data.head()
# Out:
#    customer_id  disbursed_amount  interest market    employment time_employed  \
# 0            0           23201.5   15.4840      C       Teacher     <=5 years
# 1            1            7425.0   11.2032      B    Accountant     <=5 years
# 2            2           11150.0    8.5100      A  Statistician     <=5 years
# 3            3            7600.0    5.8656      A         Other     <=5 years
# 4            4           31960.0   18.7392      E    Bus driver      >5 years
#
#   householder    income date_issued  target        loan_purpose  \
# 0        RENT   84600.0  2013-06-11       0  Debt consolidation
# 1       OWNER  102000.0  2014-05-08       0        Car purchase
# 2        RENT   69840.0  2013-10-26       0  Debt consolidation
# 3        RENT  100386.0  2015-08-20       0  Debt consolidation
# 4        RENT   95040.0  2014-07-22       0  Debt consolidation
#
#    number_open_accounts date_last_payment  number_credit_lines_12
# ...

# %% [markdown]
# # continous variables

# %% [markdown]
# # Display the mean of any two variables with continuous values

# %%
c1=data['disbursed_amount'].unique()
print(c1)
# Out:
# [23201.5   7425.   11150.   ...  6279.   12894.75 25584.  ]

# %%
c2=data['interest'].unique()
print(c2)
# Out:
# [15.484  11.2032  8.51   ... 12.9195 11.2332 11.0019]

# %%
print('Mean of disbursed amount ',c1.mean())
# Out:
# Mean of disbursed amount  13802.160685963521

# %%
print('Mean of interest ',c2.mean())
# Out:
# Mean of interest  14.025737078651684

# %% [markdown]
# # Discrete variables

# %% [markdown]
# # Print the number of discrete variables

# %%
data['number_open_accounts'].value_counts()
# Out:
# 11.0    894
# 10.0    890
# 9.0     877
# 12.0    850
# 8.0     755
# 13.0    721
# 7.0     627
# 14.0    598
# 15.0    522
# 16.0    454
# 6.0     438
# 17.0    374
# 18.0    306
# 5.0     254
# 19.0    221
# 20.0    209
# 21.0    155
# 4.0     142
# 22.0    113
# 23.0    104
# 24.0    102
# 26.0     69
# 25.0     58
# 27.0     49
# 3.0      47
# 28.0     31
# 29.0     29
# 31.0     20
# 30.0     14
# 34.0     12
# 2.0      12
# 32.0      9
# 33.0      8
# 36.0      7
# 35.0      6
# 42.0      4
# 37.0      4
# 38.0      3
# 43.0      2
# 41.0      2
# 1.0       2
# 49.0      2
# 44.0      2
# 40.0      1
# 47.0      1
# Name: number_open_accounts, dtype: int64

# %%
data['customer_id'].value_counts()
# Out:
# 2047    1
# 9518    1
# 7481    1
# 5432    1
# 9526    1
#        ..
# 2716    1
# 8857    1
# 4759    1
# 6806    1
# 0       1
# Name: customer_id, Length: 10000, dtype: int64

# %% [markdown]
# # Display the unique values of two variables with discrete values

# %%
data['number_open_accounts'].unique()
# Out:
# array([ 4., 13.,  8., 20., 14.,  5.,  9., 18., 16., 17., 12., 15.,  6.,
#        10., 11.,  7., 21., 19., 26.,  2., 22., 27., 23., 25., 24., 28.,
#         3., 30., 41., 32., 33., 31., 29., 37., 49., 34., 35., 38.,  1.,
#        36., 42., 47., 40., 44., 43.])

# %%
data['customer_id'].unique()
# Out:
# array([   0,    1,    2, ..., 9997, 9998, 9999], dtype=int64)

# %% [markdown]
# # Display the Month with most of loans issued date

# %%
data['date_issued_dt']=pd.to_datetime(data['date_issued'])

# %%
data.head()
# Out:
#    customer_id  disbursed_amount  interest market    employment time_employed  \
# 0            0           23201.5   15.4840      C       Teacher     <=5 years
# 1            1            7425.0   11.2032      B    Accountant     <=5 years
# 2            2           11150.0    8.5100      A  Statistician     <=5 years
# 3            3            7600.0    5.8656      A         Other     <=5 years
# 4            4           31960.0   18.7392      E    Bus driver      >5 years
#
#   householder    income date_issued  target        loan_purpose  \
# 0        RENT   84600.0  2013-06-11       0  Debt consolidation
# 1       OWNER  102000.0  2014-05-08       0        Car purchase
# 2        RENT   69840.0  2013-10-26       0  Debt consolidation
# 3        RENT  100386.0  2015-08-20       0  Debt consolidation
# 4        RENT   95040.0  2014-07-22       0  Debt consolidation
#
#    number_open_accounts date_last_payment  number_credit_lines_12  \
# ...

# %%
#extracting month from date variables
data['month']=data['date_issued_dt'].dt.month

# %%
data.head()
# Out:
#    customer_id  disbursed_amount  interest market    employment time_employed  \
# 0            0           23201.5   15.4840      C       Teacher     <=5 years
# 1            1            7425.0   11.2032      B    Accountant     <=5 years
# 2            2           11150.0    8.5100      A  Statistician     <=5 years
# 3            3            7600.0    5.8656      A         Other     <=5 years
# 4            4           31960.0   18.7392      E    Bus driver      >5 years
#
#   householder    income date_issued  target        loan_purpose  \
# 0        RENT   84600.0  2013-06-11       0  Debt consolidation
# 1       OWNER  102000.0  2014-05-08       0        Car purchase
# 2        RENT   69840.0  2013-10-26       0  Debt consolidation
# 3        RENT  100386.0  2015-08-20       0  Debt consolidation
# 4        RENT   95040.0  2014-07-22       0  Debt consolidation
#
#    number_open_accounts date_last_payment  number_credit_lines_12  \
# ...

# %%
data.groupby(['month']).count()
# Out:
#        customer_id  disbursed_amount  interest  market  employment  \
# month
# 1              700               700       700     700         655
# 2              584               584       584     584         536
# 3              623               623       623     623         588
# 4              816               816       816     816         779
# 5              749               749       749     749         704
# 6              700               700       700     700         665
# 7             1066              1066      1066    1066        1006
# 8              852               852       852     852         792
# 9              734               734       734     734         687
# 10            1277              1277      1277    1277        1212
# 11            1017              1017      1017    1017         944
# 12             882               882       882     882         821
#
#        time_employed  householder  income  date_issued  target  loan_purpose  \
# month
# ...

# %% [markdown]
# # Display the count of ‘Teacher’ who are ‘Owners’

# %%
data.loc[(data['employment']=='Teacher') & (data['householder']=='OWNER') ,['employment','householder']].value_counts()
# Out:
# employment  householder
# Teacher     OWNER          69
# dtype: int64

# %% [markdown]
# # Trial for Display the count of ‘Teacher’ who are ‘Owners’

# %%
teacher_owner = data.loc[(data['employment'] == 'Teacher') & (data['householder'] == 'OWNER')]
teacher_owner.reset_index(drop=True, inplace=True)

teacher_owner
teacher_owner['count'] = 1

teacher_owner.groupby(['employment', 'householder']).count()['count']
# Out:
# <ipython-input-63-51a610cdbb87>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   teacher_owner['count'] = 1
# employment  householder
# Teacher     OWNER          69
# Name: count, dtype: int64

# %%
# Out:
# employment  householder
# Teacher     OWNER          69
# dtype: int64

# %% [markdown]
# # Display the ‘Employment’ of customers who mostly ‘Rent’

# %%
data.loc[data.householder=='RENT', ['employment','householder']]
# Out:
#               employment householder
# 0                Teacher        RENT
# 2           Statistician        RENT
# 3                  Other        RENT
# 4             Bus driver        RENT
# 6              Secretary        RENT
# ...                  ...         ...
# 9991  Software developer        RENT
# 9992        Statistician        RENT
# 9994          Accountant        RENT
# 9996       Civil Servant        RENT
# 9998          Bus driver        RENT
#
# [4055 rows x 2 columns]

# %% [markdown]
# # Trials to reach the answer (Display the ‘Employment’ of customers who mostly ‘Rent’)

# %%
g=data.groupby('householder')
g

# %%
for householder,householder_df in g:
    print(householder)
    print(householder_df)
# Out:
# MORTGAGE
#       customer_id  disbursed_amount  interest market     employment  \
# 5               5           8288.75   15.2448      C   Statistician
# 10             10          21840.00    9.8952      B     Accountant
# 11             11          11400.00    7.4260      A    Taxi driver
# 13             13          31850.00   19.7306      E            NaN
# 14             14           4560.00   10.6603      B    Taxi driver
# ...           ...               ...       ...    ...            ...
# 9989         9989           7760.00   11.2332      B    Taxi driver
# 9990         9990          19200.00   14.6734      C   Statistician
# 9993         9993          11640.00   13.3083      C          Other
# 9995         9995          23750.00   11.0019      B  Civil Servant
# 9999         9999          25584.00   17.1456      D     Accountant
#
#      time_employed householder   income date_issued  target  \
# 5         >5 years    MORTGAGE  41587.0  2013-08-21       0
# ...

# %%
g.get_group('RENT')
# Out:
#       customer_id  disbursed_amount  interest market          employment  \
# 0               0           23201.5   15.4840      C             Teacher
# 2               2           11150.0    8.5100      A        Statistician
# 3               3            7600.0    5.8656      A               Other
# 4               4           31960.0   18.7392      E          Bus driver
# 6               6           27900.0   16.9670      D           Secretary
# ...           ...               ...       ...    ...                 ...
# 9991         9991           20580.0   12.0442      C  Software developer
# 9992         9992            1470.0   12.5900      C        Statistician
# 9994         9994            5520.0   10.6603      B          Accountant
# 9996         9996           11880.0   10.4923      B       Civil Servant
# 9998         9998            4850.0   13.6409      C          Bus driver
#
#      time_employed householder    income date_issued  target  \
# ...

# %%
g['employment'].unique()
# Out:
# householder
# MORTGAGE    [Statistician, Accountant, Taxi driver, nan, S...
# OWNER       [Accountant, nan, Civil Servant, Software deve...
# RENT        [Teacher, Statistician, Other, Bus driver, Sec...
# Name: employment, dtype: object

# %%
h=data.groupby('employment')
h

# %%
for employment,employment_df in h:
    print(employment)
    print(employment_df)
# Out:
# Accountant
#       customer_id  disbursed_amount  interest market  employment  \
# 1               1            7425.0   11.2032      B  Accountant
# 10             10           21840.0    9.8952      B  Accountant
# 15             15           15792.0    8.9931      B  Accountant
# 19             19           15200.0   12.4545      B  Accountant
# 29             29            2784.0   16.7900      D  Accountant
# ...           ...               ...       ...    ...         ...
# 9957         9957            8787.5   14.5403      C  Accountant
# 9973         9973           15400.0    6.6800      A  Accountant
# 9994         9994            5520.0   10.6603      B  Accountant
# 9997         9997           19950.0    8.4364      B  Accountant
# 9999         9999           25584.0   17.1456      D  Accountant
#
#      time_employed householder    income date_issued  target  \
# 1        <=5 years       OWNER  102000.0  2014-05-08       0
# ...

# %%
data[['employment','householder']]
# Out:
#          employment householder
# 0           Teacher        RENT
# 1        Accountant       OWNER
# 2      Statistician        RENT
# 3             Other        RENT
# 4        Bus driver        RENT
# ...             ...         ...
# 9995  Civil Servant    MORTGAGE
# 9996  Civil Servant        RENT
# 9997     Accountant       OWNER
# 9998     Bus driver        RENT
# 9999     Accountant    MORTGAGE
#
# [10000 rows x 2 columns]
